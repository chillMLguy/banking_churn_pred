# %% [markdown]
# # Data preprocessing
#
# In this notebook we will preprocess our data. This includes dropping unneccesary variables, creating pipeline for preprocess numerical data, categorical and creating new variables. The output of this notebook will be input of modeling notebook.

# %% [markdown]
# ## Imports and droppings
#
# Firstly we will import libraries, data and drop unimportant variables.

# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

data = pd.read_csv("data.csv")
col_to_drop = ["RowNumber", "CustomerId", "Surname"]
data = data.drop(col_to_drop, axis=1)

# %% [markdown]
# ## New features creation
#
# Now we will create three new features based on old ones to try to improve our model by catching unseen dependences.

# %%
# testing cor of new features

import matplotlib.pyplot as plt
import seaborn as sns
corr_matrix = data.corr(numeric_only=True)

plt.figure(figsize=(10, 8))

sns.heatmap(
    corr_matrix, 
    annot=True,         
    cmap='coolwarm',    
    fmt=".2f",       
    linewidths=0.5,    
    vmin=-1, vmax=1  
)

plt.show()

# %%
(data["Complain"] != data["Exited"]).sum()
# Out:
# 14
